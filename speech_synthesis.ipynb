# %% [markdown]
# <a href="https://colab.research.google.com/github/mohdravi/speech_sysnthization/blob/main/speech_synthesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###1. Installing the required modules

# %%
# !pip install TTS cutlet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 60.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 71.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 25.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 71.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
from TTS.api import TTS
from IPython.display import Audio
import librosa
import os

# %% [markdown]
# ###2. Loading the Model

# %%
#Loading the model from the coqui
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2", gpu=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/TTS/api.py:70: UserWarning: `gpu` will be deprecated. Please use `tts.to(device)` instead.
#   warnings.warn("`gpu` will be deprecated. Please use `tts.to(device)` instead.")
#  > You must confirm the following:
#  | > "I have purchased a commercial license from Coqui: licensing@coqui.ai"
#  | > "Otherwise, I agree to the terms of the non-commercial CPML: https://coqui.ai/cpml" - [y/n]
#  | | > y
#  > Downloading model to /root/.local/share/tts/tts_models--multilingual--multi-dataset--xtts_v2
# 100%|█████████▉| 1.86G/1.87G [00:29<00:00, 66.0MiB/s]
# 100%|██████████| 1.87G/1.87G [00:29<00:00, 63.3MiB/s]
# 100%|██████████| 4.37k/4.37k [00:00<00:00, 25.8kiB/s]
#
# 100%|██████████| 361k/361k [00:00<00:00, 1.73MiB/s]
# 100%|██████████| 32.0/32.0 [00:00<00:00, 112iB/s]
#  82%|████████▏ | 6.36M/7.75M [00:00<00:00, 63.6MiB/s]
#  > Model's license - CPML
#  > Check https://coqui.ai/cpml.txt for more info.
# ...

# %% [markdown]
# #Synthesization with the loaded model

# %%
wav = tts.tts("i was busy in other work",
        speaker="Kazuhiko Atallah",
        language="en")
# Out:
#  > Text splitted to sentences.
# ['i was busy in other work']
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
#  > Processing time: 2.9278199672698975
#  > Real-time factor: 1.3198893988857794

# %%
display(Audio(wav, rate=24000))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ###Cloning Voice on custom voice

# %%
# generate speech by cloning a voice using default settings
tts.tts_to_file(text="It took me quite a long time to develop a voice, and now that I have it I'm not going to be silent.",
                file_path="output.wav",
                speaker_wav=["/content/record_out.wav"],
                language="en",
                split_sentences=True
                )
# Out:
#  > Text splitted to sentences.
# ["It took me quite a long time to develop a voice, and now that I have it I'm not going to be silent."]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-cd90cac589dc> in <cell line: 0>()
#       1 # generate speech by cloning a voice using default settings
# ----> 2 tts.tts_to_file(text="It took me quite a long time to develop a voice, and now that I have it I'm not going to be silent.",
#       3                 file_path="output.wav",
#       4                 speaker_wav=["/content/record_out.wav"],
#       5                 language="en",
#
# /usr/local/lib/python3.11/dist-packages/TTS/api.py in tts_to_file(self, text, speaker, language, speaker_wav, emotion, speed, pipe_out, file_path, split_sentences, **kwargs)
#     332         self._check_arguments(speaker=speaker, language=language, speaker_wav=speaker_wav, **kwargs)
# ...
